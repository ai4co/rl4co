# %%
import torch
from torch.utils.data import TensorDataset, DataLoader

# %%
b = 100
ds = TensorDataset(torch.arange(b))
dl = DataLoader(ds, shuffle=True, batch_size=10)


x = torch.arange(3*b)
x = x.view(b, 3)

# %%
for idx in dl:
    print(idx, x[idx])
# Out:
# [tensor([71, 36, 61, 65, 17, 11, 67, 98,  1, 68])] tensor([[213, 214, 215],
#         [108, 109, 110],
#         [183, 184, 185],
#         [195, 196, 197],
#         [ 51,  52,  53],
#         [ 33,  34,  35],
#         [201, 202, 203],
#         [294, 295, 296],
#         [  3,   4,   5],
#         [204, 205, 206]])
# [tensor([18, 25, 38, 97, 60, 49, 79, 12, 95, 42])] tensor([[ 54,  55,  56],
#         [ 75,  76,  77],
#         [114, 115, 116],
#         [291, 292, 293],
#         [180, 181, 182],
#         [147, 148, 149],
#         [237, 238, 239],
#         [ 36,  37,  38],
#         [285, 286, 287],
#         [126, 127, 128]])
# [tensor([78,  7, 22, 55, 77,  8, 80, 44, 92, 39])] tensor([[234, 235, 236],
#         [ 21,  22,  23],
#         [ 66,  67,  68],
#         [165, 166, 167],
#         [231, 232, 233],
#         [ 24,  25,  26],
#         [240, 241, 242],
#         [132, 133, 134],
#         [276, 277, 278],
#         [117, 118, 119]])
# ...
